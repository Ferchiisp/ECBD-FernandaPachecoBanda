# %%
import pandas as pd

# %%
#Conjunto de datos
datos = {
    "usuario": ["Ana", "luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"],
    "edad": [22,35,28,40,19,31,26,45],
    "ciudad": ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancun", "Merida", "Tijuana","Toluca"],
    "compras_realizadas": [5,12, 3, 29, 1, 7,4,15],
    "activo": [True,False,True,True,False,True,False,True],
    "fecha_registro" : ["2026-01-10","2026-01-12","2026-02-10","2026-01-05","2026-01-17","2026-03-19","2026-42-20","2026-02-18"]
}

# %%
#Convertir a dataframe
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2026-02-10
# 3  Carolina    40       Puebla                  29    True     2026-01-05
# 4     Sofia    19       Cancun                   1   False     2026-01-17
# 5     Pedro    31       Merida                   7    True     2026-03-19
# 6     Elena    26      Tijuana                   4   False     2026-42-20
# 7     Diego    45       Toluca                  15    True     2026-02-18

# %%
#Imprime los primeros 5
df.head()
# Out:
#     usuario  edad       ciudad  compras_realizadas  activo fecha_registro
# 0       Ana    22         CDMX                   5    True     2026-01-10
# 1      luis    35    Monterrey                  12   False     2026-01-12
# 2    Martha    28  Guadalajara                   3    True     2026-02-10
# 3  Carolina    40       Puebla                  29    True     2026-01-05
# 4     Sofia    19       Cancun                   1   False     2026-01-17

# %%
#Crear un dataframe con 1000000
cantidad = 10000000

# %%
import random

# %%
nombres = ["Ana", "luis", "Martha", "Carolina", "Sofia", "Pedro", "Elena", "Diego"],
ciudades = ["CDMX", "Monterrey", "Guadalajara", "Puebla", "Cancun", "Merida", "Tijuana","Toluca"],
categorias = ["Tecnologia","Ropa","Hogar","Videojugeos","Deportes","Calzado","Blancos","Ninos"]

# %%
dfMillon = pd.DataFrame ({
    "nombre": [random.choice(nombres) for _ in range(cantidad)],
    "edad": [random.randint(18,70) for _ in range(cantidad)],
    "salario": [round(random.uniform(5000, 50000),2) for _ in range(cantidad)],
    "activo": [random.choice([True,False]) for _ in range(cantidad)],
    "categoria": [random.choice(categorias) for _ in range(cantidad)],
    "ciudad": [random.choice(ciudades) for _ in range(cantidad)],
    "anio_registro": [random.randint(2020,2026) for _ in range(cantidad)]
})

# %%
dfMillon.shape
# Out:
# (10000000, 7)

# %%
dfMillon.dtypes
# Out:
# nombre            object
# edad               int64
# salario          float64
# activo              bool
# categoria            str
# ciudad            object
# anio_registro      int64
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                  132
# nombre           128000000
# edad               8000000
# salario            8000000
# activo             1000000
# categoria         64124494
# ciudad           128000000
# anio_registro      8000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum() /1024**2
# Out:
# np.float64(3291.37290763855)
