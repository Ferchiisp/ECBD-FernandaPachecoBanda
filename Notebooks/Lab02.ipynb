# %%
import pandas as pd

# %%
datos = {
    "influencer": ["Juanga","JenniR","Domelupe","Maria","Sergio","Chona","Liam"],
    "likes": [80000,70000,100000,90000,30000,20000,700000],
    "comentarios": ["Amo sus canciones","Querida socia","Tqm Domee","Simplemente Maria","El bailador","Una famosa persona","Liam Noooooo"],
    "fecha": ["2026-01-19","2026-01-14","2026-01-24","2026-01-15","2026-03-17","2026-03-19","2026-04-09"]
}

# %%
df = pd.DataFrame(datos)

# %%
print(df)
# Out:
#   influencer   likes         comentarios       fecha
# 0     Juanga   80000   Amo sus canciones  2026-01-19
# 1     JenniR   70000       Querida socia  2026-01-14
# 2   Domelupe  100000           Tqm Domee  2026-01-24
# 3      Maria   90000   Simplemente Maria  2026-01-15
# 4     Sergio   30000         El bailador  2026-03-17
# 5      Chona   20000  Una famosa persona  2026-03-19
# 6       Liam  700000        Liam Noooooo  2026-04-09

# %%
cantidad = 1000000

# %%
import random

# %%
influencers = ["Juanga","JenniR","Domelupe","Aespa","Sergio","Chona","Liam"],
likes = [80000,70000,100000,90000,30000,20000,700000],
comentarios = ["Amo sus canciones","Querida socia","Tqm","Next level","El bailador","Una famosa persona","Liam Noooooo"],
fechas = ["2026-01-19","2026-01-14","2026-01-24","2026-01-15","2026-03-17","2026-03-19","2026-04-09"]

# %%
dfMillon = pd.DataFrame ({
    "influencer": [random.choice(influencers) for _ in range(cantidad)],
    "likes":[random.randint(1000,1000000) for _ in range(cantidad)],
    "comentarios": [random.choice(comentarios) for _ in range(cantidad)],
    "fechas":[random.randint(2020,2026) for _ in range(cantidad)]
})

# %%
df.head()
# Out:
#   influencer   likes        comentarios       fecha
# 0     Juanga   80000  Amo sus canciones  2026-01-19
# 1     JenniR   70000      Querida socia  2026-01-14
# 2   Domelupe  100000          Tqm Domee  2026-01-24
# 3      Maria   90000  Simplemente Maria  2026-01-15
# 4     Sergio   30000        El bailador  2026-03-17

# %%
df.columns
# Out:
# Index(['influencer', 'likes', 'comentarios', 'fecha'], dtype='object')
